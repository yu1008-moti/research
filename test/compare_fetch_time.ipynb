# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import os
import requests
import pandas as pd
from typing import List, Dict, Any
from matplotlib import pyplot as plt
import seaborn as sns
import time

# %%
def _get_response_prices(date:str, headers:dict) -> Dict[str, Any]:
    resp = requests.get(
        "https://api.jquants.com/v2/equities/bars/daily",
        params  = {"date": date},
        headers = headers,
    )
    return resp.json()['data']

# %%
def _get_response_codes(date:str, headers:dict) -> Dict[str, Any]:
    resp = requests.get(
        "https://api.jquants.com/v2/equities/master",
        params  = {"date": date},
        headers = headers,
    )
    return resp.json()['data']

# %%
def _get_response_fins(date:str, headers:dict) -> Dict[str, Any]:
    resp = requests.get(
        "https://api.jquants.com/v2/fins/summary",
        params  = {"date": date},
        headers = headers,
    )
    return resp.json()['data']

# %%
def _get_response_margin_interest(date:str, headers:dict) -> Dict[str, Any]:
    resp = requests.get(
        "https://api.jquants.com/v2/markets/margin-interest",
        params  = {"date": date},
        headers = headers,
    )
    return resp.json()['data']

# %%
date = "2026-04-10"
api_key = os.getenv('jq_api_key')
start_price_time = time.time()
resp_prices = _get_response_prices(date, headers = {"x-api-key": api_key})
end_price_time = time.time()
print(f"Prices API call time: {end_price_time - start_price_time}")
api_time_prices = end_price_time - start_price_time

start_codes_time = time.time()
resp_codes  = _get_response_codes(date, headers = {"x-api-key": api_key})
end_codes_time = time.time()
print(f"Codes API call time: {end_codes_time - start_codes_time}")
api_time_codes = end_codes_time - start_codes_time

start_fins_time = time.time()
resp_fins   = _get_response_fins(date, headers = {"x-api-key": api_key})
end_fins_time = time.time()
print(f"Fins API call time: {end_fins_time - start_fins_time}")
api_time_fins = end_fins_time - start_fins_time

start_margin_time = time.time()
resp_margin = _get_response_margin_interest(date, headers = {"x-api-key": api_key})
end_margin_time = time.time()
print(f"Margin API call time: {end_margin_time - start_margin_time}")
api_time_margin = end_margin_time - start_margin_time
# Out:
# Prices API call time: 3.665135145187378
# Codes API call time: 1.4773344993591309
# Fins API call time: 0.27930188179016113
# Margin API call time: 0.920403242111206

# %%
start_price_time = time.time()
prices_csv = pd.DataFrame.from_records(resp_prices)
prices_csv.to_csv("prices.csv", index=False)
end_price_time = time.time()
print(f"Prices CSV write time: {end_price_time - start_price_time}")
write_time_prices = end_price_time - start_price_time

start_codes_time = time.time()
codes_csv  = pd.DataFrame.from_records(resp_codes)
codes_csv.to_csv("codes.csv", index=False)
end_codes_time = time.time()
print(f"Codes CSV write time: {end_codes_time - start_codes_time}")
write_time_codes = end_codes_time - start_codes_time

start_fins_time = time.time()
fins_csv   = pd.DataFrame.from_records(resp_fins)
fins_csv.to_csv("fins.csv", index=False)
end_fins_time = time.time()
print(f"Fins CSV write time: {end_fins_time - start_fins_time}")
write_time_fins = end_fins_time - start_fins_time

start_margin_time = time.time()
margin_csv = pd.DataFrame.from_records(resp_margin)
margin_csv.to_csv("margin.csv", index=False)
end_margin_time = time.time()
print(f"Margin CSV write time: {end_margin_time - start_margin_time}") 
write_time_margin = end_margin_time - start_margin_time
# Out:
# Prices CSV write time: 0.07326722145080566
# Codes CSV write time: 0.019043922424316406
# Fins CSV write time: 0.013829231262207031
# Margin CSV write time: 0.0

# %%
plot_data = {
    "API Call Time (s)": [api_time_prices, api_time_codes, api_time_fins, api_time_margin],
    "CSV Write Time (s)": [write_time_prices, write_time_codes, write_time_fins, write_time_margin]
}
df_plot = pd.DataFrame(plot_data, index=["Prices", "Codes", "Fins", "Margin"])
df_plot.plot(
    kind='bar', 
    figsize=(10, 6), 
    title="API Call Time and CSV Write Time",
    xlabel="Data Type",
    ylabel="$Time (s)$", 
    legend=True, 
    rot=0,
    grid=True,
)
plt.tight_layout()
plt.show()
